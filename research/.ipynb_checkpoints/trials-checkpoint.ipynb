# %%
# %pwd
# Out:
# 'c:\\Users\\DELL\\Documents\\MediBot\\research\\.ipynb_checkpoints'

# %%
from langchain_community.document_loaders import PyPDFLoader,DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
pip install -U google-genai
# Out:
# Requirement already satisfied: google-genai in c:\users\dell\anaconda3\lib\site-packages (1.31.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\dell\anaconda3\lib\site-packages (from google-genai) (4.10.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\dell\anaconda3\lib\site-packages (from google-genai) (2.40.3)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\dell\anaconda3\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from google-genai) (2.10.3)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\dell\anaconda3\lib\site-packages (from google-genai) (2.32.3)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\dell\anaconda3\lib\site-packages (from google-genai) (9.0.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\dell\anaconda3\lib\site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\dell\anaconda3\lib\site-packages (from google-genai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\dell\anaconda3\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\anaconda3\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\dell\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\dell\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\dell\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\dell\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
def load_pdf_files(data):
    loader = DirectoryLoader(
        data,
        glob="*.pdf",
        loader_cls=PyPDFLoader
    )
    documents=loader.load()
    return documents

# %%
extracted_docs = load_pdf_files(r"C:\Users\DELL\Documents\MEDIBOT\data")

# %%
pip install pypdf
# Out:
# Requirement already satisfied: pypdf in c:\users\dell\anaconda3\lib\site-packages (6.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
extracted_docs
print(len(extracted_docs))
# Out:
# 637

# %%
from typing import List
from langchain.schema import Document

# %%
def filter_to_minimal_docs(docs:List[Document]) -> List[Document]:

    minimal_docs : List[Document] = [] 
    for doc in docs:
        src=doc.metadata.get("source")
        minimal_docs.append(
            Document(
               page_content=doc.page_content,
               metadata={
                "source": src
            }
        )
    )
    return minimal_docs
minimal_docs=filter_to_minimal_docs(extracted_docs)

# %%
##################Chunking operation

def text_split(minimal_docs: List[Document]) -> List[Document]:
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=300,
        chunk_overlap=100,
        length_function=len
    )
    texts_chunk = text_splitter.split_documents(minimal_docs)
    return texts_chunk

texts_chunk = text_split(minimal_docs)

# %%
pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\dell\anaconda3\lib\site-packages (5.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\dell\anaconda3\lib\site-packages (from sentence-transformers) (4.55.2)
# Requirement already satisfied: tqdm in c:\users\dell\anaconda3\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\dell\anaconda3\lib\site-packages (from sentence-transformers) (2.8.0)
# Requirement already satisfied: scikit-learn in c:\users\dell\anaconda3\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\dell\anaconda3\lib\site-packages (from sentence-transformers) (0.34.4)
# Requirement already satisfied: Pillow in c:\users\dell\anaconda3\lib\site-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\dell\anaconda3\lib\site-packages (from sentence-transformers) (4.12.2)
# Requirement already satisfied: filelock in c:\users\dell\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\dell\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dell\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\dell\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\dell\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\dell\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\dell\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx in c:\users\dell\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dell\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.8.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings 

def download_embeddings():
    model_name = "sentence-transformers/all-MiniLM-L6-v2"
    
    embeddings = HuggingFaceEmbeddings(
        model_name=model_name
        
    )                                    ###initialize the embeding model 
    return embeddings


embedding = download_embeddings()

# %%
embedding.embed_query("hello world")
# Out:
# [-0.034477200359106064,
#  0.031023219227790833,
#  0.0067349993623793125,
#  0.02610897459089756,
#  -0.03936201333999634,
#  -0.16030248999595642,
#  0.06692397594451904,
#  -0.006441470701247454,
#  -0.04745051637291908,
#  0.014758859761059284,
#  0.07087533175945282,
#  0.05552757531404495,
#  0.019193289801478386,
#  -0.026251329109072685,
#  -0.010109508410096169,
#  -0.026940548792481422,
#  0.022307483479380608,
#  -0.022226618602871895,
#  -0.14969265460968018,
#  -0.01749304309487343,
#  0.007676269859075546,
#  0.05435226485133171,
#  0.003254482988268137,
#  0.03172600269317627,
#  -0.0846213772892952,
#  -0.02940598875284195,
#  0.051595672965049744,
#  0.04812409356236458,
#  -0.003314794274047017,
#  -0.05827922374010086,
#  0.041969284415245056,
#  0.022210709750652313,
#  0.1281888633966446,
#  -0.022338956594467163,
#  -0.011656241491436958,
#  0.06292833387851715,
#  -0.032876305282115936,
#  -0.09122610837221146,
#  -0.03117538057267666,
#  0.05269957706332207,
#  0.047034792602062225,
#  -0.08420304954051971,
#  -0.0300561785697937,
#  -0.020744718611240387,
#  0.009517784230411053,
#  -0.003721792483702302,
#  0.007343328557908535,
#  -0.006582724861800671,
#  0.016632026061415672,
#  0.03236645832657814,
#  0.03794251009821892,
#  -0.036376021802425385,
#  -0.006910946220159531,
#  0.00015967455692589283,
#  -0.001633585779927671,
#  -0.02727823331952095,
#  -0.028038015589118004,
#  0.04968152567744255,
#  -0.028867164626717567,
#  -0.002418051240965724,
#  0.014774874784052372,
#  0.009764568880200386,
#  0.005797559395432472,
#  0.013486078940331936,
#  0.005567895248532295,
#  0.0372270792722702,
#  0.007232493255287409,
#  0.04015621170401573,
#  0.08150321245193481,
#  0.07199164479970932,
#  -0.01305615995079279,
#  -0.04288202524185181,
#  -0.011011214926838875,
#  0.004897830542176962,
#  -0.009229752235114574,
#  0.03519146889448166,
#  -0.05103498697280884,
#  -1.5714373802211412e-08,
#  -0.08862444013357162,
#  0.0239093154668808,
#  -0.01623874343931675,
#  0.03170047700405121,
#  0.027284175157546997,
#  0.05246879905462265,
#  -0.04707096517086029,
#  -0.058847445994615555,
#  -0.0632082149386406,
#  0.04088853672146797,
#  0.049827940762043,
#  0.10655166208744049,
#  -0.07450233399868011,
#  -0.012495458126068115,
#  0.018370643258094788,
#  0.039474066346883774,
#  -0.024797869846224785,
#  0.01451625395566225,
#  -0.03706921264529228,
#  0.020015696063637733,
#  -4.8594301915727556e-05,
#  0.00986657477915287,
#  0.024838784709572792,
#  -0.05245809629559517,
#  0.029314136132597923,
#  -0.08719196915626526,
#  -0.014499745331704617,
#  0.026019057258963585,
#  -0.018746383488178253,
#  -0.07620513439178467,
#  0.035043250769376755,
#  0.10363949090242386,
#  -0.02805054932832718,
#  0.012718234211206436,
#  -0.07632549107074738,
#  -0.018652433529496193,
#  0.02497669868171215,
#  0.08144541829824448,
#  0.06875890493392944,
#  -0.0640566349029541,
#  -0.08389392495155334,
#  0.061362382024526596,
#  -0.033545587211847305,
#  -0.10615341365337372,
#  -0.04008050262928009,
#  0.03253019228577614,
#  0.07662486284971237,
#  -0.07301613688468933,
#  0.0003375994274392724,
#  -0.04087162762880325,
#  -0.0757884681224823,
#  0.027527686208486557,
#  0.07462546974420547,
#  0.01771729253232479,
#  0.09121839702129364,
#  0.11022018641233444,
#  0.0005698270397260785,
#  0.05146332085132599,
#  -0.014551276341080666,
#  0.03323199599981308,
#  0.023792244493961334,
#  -0.022889798507094383,
#  0.03893755376338959,
#  0.030206795781850815]

# %%
from dotenv import load_dotenv 
import os
load_dotenv()
# Out:
# True

# %%
PINECONE_API_KEY=os.getenv("PINECONE_API_KEY")
GEMINI_API_KEY=os.getenv("GEMINI_API_KEY")

os.environ["PINECONE_API_KEY"] = PINECONE_API_KEY
os.environ["GEMINI_API_KEY"] = GEMINI_API_KEY

# %%
pip install pinecone
# Out:
# Requirement already satisfied: pinecone in c:\users\dell\anaconda3\lib\site-packages (7.3.0)
# Requirement already satisfied: certifi>=2019.11.17 in c:\users\dell\anaconda3\lib\site-packages (from pinecone) (2025.8.3)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in c:\users\dell\anaconda3\lib\site-packages (from pinecone) (1.7.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in c:\users\dell\anaconda3\lib\site-packages (from pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\dell\anaconda3\lib\site-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\dell\anaconda3\lib\site-packages (from pinecone) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\dell\anaconda3\lib\site-packages (from pinecone) (2.3.0)
# Requirement already satisfied: packaging<25.0,>=24.2 in c:\users\dell\anaconda3\lib\site-packages (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (24.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\dell\anaconda3\lib\site-packages (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (3.7)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pinecone import Pinecone
pinecone_api_key = PINECONE_API_KEY

pc = Pinecone(api_key=pinecone_api_key)

# %%
from pinecone import ServerlessSpec

index_name= "medicalbot"

if not pc.has_index(index_name):
    pc.create_index(
        name=index_name,
        dimension=384,
        metric="cosine",
        spec=ServerlessSpec(cloud="aws",region="us-east-1")


    )

# %%
pip install langchain-pinecone
# Out:
# Requirement already satisfied: langchain-pinecone in c:\users\dell\anaconda3\lib\site-packages (0.2.11)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.34 in c:\users\dell\anaconda3\lib\site-packages (from langchain-pinecone) (0.3.74)
# Requirement already satisfied: pinecone<8.0.0,>=6.0.0 in c:\users\dell\anaconda3\lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (7.3.0)
# Requirement already satisfied: numpy>=1.26.4 in c:\users\dell\anaconda3\lib\site-packages (from langchain-pinecone) (2.1.3)
# Requirement already satisfied: langchain-tests<1.0.0,>=0.3.7 in c:\users\dell\anaconda3\lib\site-packages (from langchain-pinecone) (0.3.20)
# Requirement already satisfied: langchain-openai>=0.3.11 in c:\users\dell\anaconda3\lib\site-packages (from langchain-pinecone) (0.3.30)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (0.4.14)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (4.12.2)
# Requirement already satisfied: packaging>=23.2 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (24.2)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (2.10.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dell\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (2.1)
# Requirement already satisfied: pytest<9,>=7 in c:\users\dell\anaconda3\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (8.3.4)
# Requirement already satisfied: pytest-asyncio<1,>=0.20 in c:\users\dell\anaconda3\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.26.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.28.1)
# Requirement already satisfied: syrupy<5,>=4 in c:\users\dell\anaconda3\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (4.9.1)
# Requirement already satisfied: pytest-socket<1,>=0.6.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.7.0)
# Requirement already satisfied: pytest-benchmark in c:\users\dell\anaconda3\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (5.1.0)
# Requirement already satisfied: pytest-codspeed in c:\users\dell\anaconda3\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (4.0.0)
# Requirement already satisfied: pytest-recording in c:\users\dell\anaconda3\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.13.4)
# Requirement already satisfied: vcrpy>=7.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (7.0.0)
# Requirement already satisfied: anyio in c:\users\dell\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (4.10.0)
# Requirement already satisfied: certifi in c:\users\dell\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.0.9)
# Requirement already satisfied: idna in c:\users\dell\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\dell\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.16.0)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in c:\users\dell\anaconda3\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.7.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in c:\users\dell\anaconda3\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\dell\anaconda3\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.0.post0)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\dell\anaconda3\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\dell\anaconda3\lib\site-packages (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.32.3)
# Requirement already satisfied: aiohttp>=3.9.0 in c:\users\dell\anaconda3\lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (3.11.10)
# Requirement already satisfied: aiohttp-retry<3.0.0,>=2.9.1 in c:\users\dell\anaconda3\lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.1)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.4.6)
# Requirement already satisfied: iniconfig in c:\users\dell\anaconda3\lib\site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.1.1)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (3.3.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\dell\anaconda3\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.18.0)
# Requirement already satisfied: openai<2.0.0,>=1.99.9 in c:\users\dell\anaconda3\lib\site-packages (from langchain-openai>=0.3.11->langchain-pinecone) (1.99.9)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\dell\anaconda3\lib\site-packages (from langchain-openai>=0.3.11->langchain-pinecone) (0.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\dell\anaconda3\lib\site-packages (from openai<2.0.0,>=1.99.9->langchain-openai>=0.3.11->langchain-pinecone) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\dell\anaconda3\lib\site-packages (from openai<2.0.0,>=1.99.9->langchain-openai>=0.3.11->langchain-pinecone) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\dell\anaconda3\lib\site-packages (from openai<2.0.0,>=1.99.9->langchain-openai>=0.3.11->langchain-pinecone) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\dell\anaconda3\lib\site-packages (from openai<2.0.0,>=1.99.9->langchain-openai>=0.3.11->langchain-pinecone) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\anaconda3\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\dell\anaconda3\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (2.27.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\dell\anaconda3\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai>=0.3.11->langchain-pinecone) (2024.11.6)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\dell\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\dell\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\dell\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (0.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.5.3->pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.17.0)
# Requirement already satisfied: wrapt in c:\users\dell\anaconda3\lib\site-packages (from vcrpy>=7.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.17.0)
# Requirement already satisfied: py-cpuinfo in c:\users\dell\anaconda3\lib\site-packages (from pytest-benchmark->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (9.0.0)
# Requirement already satisfied: cffi>=1.17.1 in c:\users\dell\anaconda3\lib\site-packages (from pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.17.1)
# Requirement already satisfied: rich>=13.8.1 in c:\users\dell\anaconda3\lib\site-packages (from pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (13.9.4)
# Requirement already satisfied: pycparser in c:\users\dell\anaconda3\lib\site-packages (from cffi>=1.17.1->pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (2.21)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\anaconda3\lib\site-packages (from rich>=13.8.1->pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\lib\site-packages (from rich>=13.8.1->pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.1->pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_pinecone import PineconeVectorStore

docsearch = PineconeVectorStore.from_documents(
    documents=texts_chunk,
    embedding=embedding,
    index_name=index_name
)

# %%
##Load Existing Index

from langchain_pinecone import PineconeVectorStore
docsearch = PineconeVectorStore.from_existing_index(
    index_name=index_name,
    embedding=embedding
)

# %%
###Add moree data  to pinecone index
sakhd=Document(
    page_content="sakhd means Sakshi D which is my name and email is also named as dsakhi20@gmail.com",
    metadata={"source":"Youtube"}
)

# %%
pip install langchain-google-genai google-generativeai
# Out:
# Requirement already satisfied: langchain-google-genai in c:\users\dell\anaconda3\lib\site-packages (2.0.10)
# Requirement already satisfied: google-generativeai in c:\users\dell\anaconda3\lib\site-packages (0.8.5)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.37 in c:\users\dell\anaconda3\lib\site-packages (from langchain-google-genai) (0.3.74)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\dell\anaconda3\lib\site-packages (from langchain-google-genai) (2.10.3)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\dell\anaconda3\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\dell\anaconda3\lib\site-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in c:\users\dell\anaconda3\lib\site-packages (from google-generativeai) (2.179.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\dell\anaconda3\lib\site-packages (from google-generativeai) (2.40.3)
# Requirement already satisfied: protobuf in c:\users\dell\anaconda3\lib\site-packages (from google-generativeai) (5.29.3)
# Requirement already satisfied: tqdm in c:\users\dell\anaconda3\lib\site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\users\dell\anaconda3\lib\site-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\dell\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.4.14)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dell\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\dell\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\dell\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\dell\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\dell\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\dell\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\dell\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.23.0)
# Requirement already satisfied: anyio in c:\users\dell\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\dell\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.3.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\dell\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\dell\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\dell\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\dell\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.0)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from tqdm->google-generativeai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in c:\users\dell\anaconda3\lib\site-packages (2.0.10)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-generativeai<0.9.0,>=0.8.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-google-genai) (0.8.5)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.37 in c:\users\dell\anaconda3\lib\site-packages (from langchain-google-genai) (0.3.74)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\dell\anaconda3\lib\site-packages (from langchain-google-genai) (2.10.3)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\dell\anaconda3\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\dell\anaconda3\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.25.1)
# Requirement already satisfied: google-api-python-client in c:\users\dell\anaconda3\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.179.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\dell\anaconda3\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.40.3)
# Requirement already satisfied: protobuf in c:\users\dell\anaconda3\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (5.29.3)
# Requirement already satisfied: tqdm in c:\users\dell\anaconda3\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\users\dell\anaconda3\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\dell\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.32.3)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.4.14)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dell\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\dell\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\dell\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.4.8)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\dell\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\dell\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\dell\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\dell\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.23.0)
# Requirement already satisfied: anyio in c:\users\dell\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\dell\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.37->langchain-google-genai) (1.3.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\dell\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\dell\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\dell\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\dell\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (3.2.0)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from tqdm->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
import os

chatModel = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    google_api_key=os.getenv("GEMINI_API_KEY")
)

# %%
import time

time.sleep(2)

# %%
docsearch.add_documents(documents=[sakhd])
# Out:
# ['b48fcebb-7b05-4603-aab8-1e2fcddf69f6']

# %%
retriever = docsearch.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 1}
)

# %%
retreived_docs = retriever.invoke("What is acne?")
retreived_docs
# Out:
# [Document(id='0b667ee8-6084-43d9-ae4c-edbff0816402', metadata={'creationdate': '2004-12-18T17:00:02-05:00', 'creator': 'PyPDF', 'moddate': '2004-12-18T16:15:31-06:00', 'page': 239.0, 'page_label': '240', 'producer': 'PDFlib+PDI 5.0.0 (SunOS)', 'source': 'C:\\Users\\DELL\\Documents\\MEDIBOT\\data\\data.pdf', 'total_pages': 637.0}, page_content='severe, disfiguring acne.\nAcne is a skin condition that occurs when pores or\nhair follicles become blocked. This allows a waxy\nmaterial, sebum, to collect inside the pores or follicles.\nNormally, sebum flows out onto the skin and hair to\nform a protective coating, but when it cannot get out,')]

# %%
pip install langchain-google-genai --upgrade
# Out:
# Requirement already satisfied: langchain-google-genai in c:\users\dell\anaconda3\lib\site-packages (2.0.10)
# Collecting langchain-google-genai
#   Using cached langchain_google_genai-2.1.9-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-google-genai) (1.2.0)
# Collecting google-ai-generativelanguage<0.7.0,>=0.6.18 (from langchain-google-genai)
#   Using cached google_ai_generativelanguage-0.6.18-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.68 in c:\users\dell\anaconda3\lib\site-packages (from langchain-google-genai) (0.3.74)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\dell\anaconda3\lib\site-packages (from langchain-google-genai) (2.10.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.25.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\dell\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.40.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\dell\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\dell\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.29.3)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.32.3)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\dell\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (4.9.1)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (0.4.14)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (4.12.2)
# Requirement already satisfied: packaging>=23.2 in c:\users\dell\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dell\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\dell\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\dell\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.4.8)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\dell\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\dell\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\dell\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\dell\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (0.23.0)
# Requirement already satisfied: anyio in c:\users\dell\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\dell\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (1.3.0)
# Using cached langchain_google_genai-2.1.9-py3-none-any.whl (49 kB)
# Using cached google_ai_generativelanguage-0.6.18-py3-none-any.whl (1.4 MB)
# Installing collected packages: google-ai-generativelanguage, langchain-google-genai
#
#   Attempting uninstall: google-ai-generativelanguage
#
#     Found existing installation: google-ai-generativelanguage 0.6.15
#
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#     Uninstalling google-ai-generativelanguage-0.6.15:
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#   Attempting uninstall: langchain-google-genai
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#     Found existing installation: langchain-google-genai 2.0.10
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#     Uninstalling langchain-google-genai-2.0.10:
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#       Successfully uninstalled langchain-google-genai-2.0.10
#    ---------------------------------------- 0/2 [google-ai-generativelanguage]
#    ---------------------------------------- 2/2 [langchain-google-genai]
#
# Successfully installed google-ai-generativelanguage-0.6.18 langchain-google-genai-2.1.9
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.18 which is incompatible.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os

GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

chatModel = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",  
    google_api_key=GEMINI_API_KEY
)

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

# %%
from langchain.prompts import ChatPromptTemplate

system_prompt = (
    "You are a Medical assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer the question. "
    "If you don't know the answer, say that you don't know. "
    "Use three sentences maximum and keep the answer concise.\n\n"
    "{context}"
)


prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

# %%
question_answer_chain = create_stuff_documents_chain(chatModel,prompt)
rag_chain = create_retrieval_chain(retriever,question_answer_chain)

# %%
response = rag_chain.invoke({"input":"what is acne?"})
print(response["answer"])
# Out:
# Acne is a skin condition caused by blocked pores or hair follicles.  This blockage traps sebum, a waxy material, leading to pimples and other skin blemishes.  Severe cases can result in disfiguring acne.

# %%
response = rag_chain.invoke({"input":"what is acromegaly?"})
print(response["answer"])
# Out:
# Based on the provided text, acromegaly is a condition that can be recognized and treated.  Information on its specific characteristics is not included in these abstracts.  More details would be needed for a complete explanation.
